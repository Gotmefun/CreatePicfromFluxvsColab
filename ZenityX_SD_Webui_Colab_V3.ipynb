# %% [markdown]
# [![00002-3144609175.png](https://i.postimg.cc/GmNDf37J/00002-3144609175.png)](https://www.facebook.com/zenityXAiStudio)
#
# ## ZenityX Colab V3.0 ⚡💓 😃
#
# ต้องการฟังชั่นเพิ่มเติม หรือ พบปัญหาการใช้งาน โปรดติดต่อ [ZenityX](https://www.facebook.com/zenityXAiStudio)
#
# 📝 สมัคร Google Colab Pro [คลิกที่นี่](https://colab.research.google.com/signup)
#
#
# > ราคา 343฿ ต่อเดือน ใช้งานได้ 57 ชั่วโมง หลังจากนั่นใช้งานได้ 4-8 ชม. ต่อวัน
#
#
# สามารถดาวน์โหลดโมเดลเข้า Google Drive โดยใส่ไว้ใน โฟลเดอร์ หลัก **SD-Model**
#
# - Checkpoint สำหรับใส่โมเดล Checkpoint
# - Lora สำหรับใส่โมเดล Lora
# - ControlNet สำหรับใส่โมเดล ControlNet
# - VAE สำหรับใส่โมเดล VAE
# - embeddings สำหรับใส่ embeddings
#
# วิธีใช้งาน
# 1. ใช้งานครั้งแรกให้ Run "**2.0. (Run ครั้งแรกครั้งเดียวเท่านั่น) สำหรับสร้างโฟลเดอร์ และดาวน์โหลดโมเดล ลง Google Drive**" ถ้าเคย Run หรือมีเตรียมไว้แล้ว ให้ข้ามได้เลย
# 2. กด Run ในข้อ 1.0.
# 3. มีปัญหา ให้กด Run ซ้ำอีกครั้งเพื่อหยุด (Stop) แล้ว Run ข้อ 1.0.2
#
# *หมายเหตุ : จำเป็นต้องมีพื้นที่ใน Google Drive 6Gb เพื่อใช้งาน*
#
#
# ---
#
# ### ⭐ พื้นที่ประชาสัมพันธ์ : เปิดคอร์ส Flux AI PowerUp with ComfyUI 🚀 ที่จะพาคุณเจาะลึกการใช้งาน Flux AI ตั้งแต่พื้นฐาน จนถึงขั้นสูง ทัก [Inbox Facebook](https://www.facebook.com/zenityXAiStudio) ได้เลยนะครับ
#
#
# ---
#
# การเรียนรู้คือการเดินทางที่ไม่มีวันจบสิ้น สมัครเรียน AI กับ ZenityX ได้ทั้ง Skill และได้สนับสนุนผู้พัฒนา เรามีกลุ่ม Line Openchat สำหรับนักเรียน เพื่อสอบถามข้อมูลต่างๆได้ 24 ชม. คอร์สกลุ่มฟรีทุกอาทิตย์ และคอยอัพเดตฟังชั่นใหม่ๆ ให้ตลอดด้วยนะ

# %% [markdown]
# # 1.0 Start Webui 🚩

# %%
# @title ## 1.0.1 Run ที่นี่ (ถ้ารันครั้งแรกให้รัน 2.0.1 ก่อน!) { form-width: "30%" }

# @markdown **เริ่ม Run ที่นี่**  โค้ดจะใช้เวลารันประมาณ 15 นาที หลังจากนั้นจะขึ้น 3 ลิงก์ติดกันในช่องรันโค้ด คลิกที่ลิงก์ใดก็ได้ (แนะนำลิงก์ล่างสุด) และเปิดหน้านี้ค้างไว้ หลังใช้งาน WebUI เสร็จแล้ว อย่าลืมปิดหน้านี้หรือคลิก **Disconnect and delete runtime** ทุกครั้ง

# **Import Libraries**
from IPython.display import Javascript, clear_output, display, HTML
from google.colab import drive
import os
import shutil

# **Adjust IFrame Height**
display(Javascript('''google.colab.output.setIframeHeight(0, true, {maxHeight: 500})'''))

# **Mount Google Drive**
# %cd /content
drive.mount('/content/drive')

# **Set Environment Variables**
# %env TF_CPP_MIN_LOG_LEVEL=1
# !wget -q https://github.com/camenduru/gperftools/releases/download/v1.0/libtcmalloc_minimal.so.4 -O /content/libtcmalloc_minimal.so.4
# %env LD_PRELOAD=/content/libtcmalloc_minimal.so.4

# **Update and Install Dependencies**
# !apt-get update -qq
# !apt-get install -y aria2 libcairo2-dev pkg-config python3-dev

# **Install Python Packages**
# !pip install -q --upgrade torch==2.6.0 torchvision torchaudio torchdata torchtext --index-url https://download.pytorch.org/whl/cu124
# !pip install xformers==0.0.29.post3
# !pip install --upgrade transformers

# **Clone Repositories**
# %cd /content
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# !git clone https://huggingface.co/embed/negative /content/stable-diffusion-webui/embeddings/negative

# **Download Models**
# !aria2c -q -c -x 16 -s 16 -k 1M https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth -d /content/stable-diffusion-webui/models/ESRGAN -o 4x-UltraSharp.pth
# !aria2c -q -c -x 16 -s 16 -k 1M https://huggingface.co/uwg/upscaler/resolve/main/ESRGAN/8x_NMKD-Superscale_150000_G.pth -d /content/stable-diffusion-webui/models/ESRGAN -o 8x_NMKD-Superscale_150000_G.pth
# !aria2c -q -c -x 16 -s 16 -k 1M https://huggingface.co/gemasai/8x_NMKD-Faces_160000_G/blob/main/8x_NMKD-Faces_160000_G.pth -d /content/stable-diffusion-webui/models/ESRGAN -o 8x_NMKD-Faces_160000_G.pth

# **Install Extensions**
extensions = {
    "tunnels": "https://github.com/camenduru/tunnels",
    "a1111-sd-webui-tagcomplete": "https://github.com/DominikDoom/a1111-sd-webui-tagcomplete",
    "ultimate-upscale-for-automatic1111": "https://github.com/Coyote-A/ultimate-upscale-for-automatic1111",
    "sd-webui-infinite-image-browsing": "https://github.com/zanllp/sd-webui-infinite-image-browsing",
    "sd-webui-controlnet": "https://github.com/Mikubill/sd-webui-controlnet",
    "adetailer": "https://github.com/Bing-su/adetailer",
    "batchlinks-webui": "https://github.com/etherealxx/batchlinks-webui",
    "Config-Presets": "https://github.com/Zyin055/Config-Presets.git"
}

for name, repo in extensions.items():
    # !git clone {repo} /content/stable-diffusion-webui/extensions/{name}

# **Download Config-Presets Files**
config_presets_files = {
    "config-img2img-custom-tracked-components.txt": "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/Config-Presets/config-img2img-custom-tracked-components.txt",
    "config-img2img.json": "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/V3/config-img2img.json",
    "config-txt2img-custom-tracked-components.txt": "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/Config-Presets/config-txt2img-custom-tracked-components.txt",
    "config-txt2img.json": "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/V3/config-txt2img.json"
}

for filename, url in config_presets_files.items():
    # !wget -q -O /content/stable-diffusion-webui/extensions/Config-Presets/{filename} {url}

# @title ### ส่วนเสริมเพิ่มเติม (เลือกเฉพาะที่ใช้งานเท่านั้น)

# **Optional Extensions**

Animatediff = False  # @param {type:"boolean"}
if Animatediff:
    # !git clone https://github.com/continue-revolution/sd-webui-animatediff /content/stable-diffusion-webui/extensions/sd-webui-animatediff
    # Motion module
    # !aria2c -q -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/159987 -d /content/stable-diffusion-webui/extensions/sd-webui-animatediff/model
    # !aria2c -q -c -x 16 -s 16 -k 1M https://huggingface.co/conrevo/AnimateDiff-A1111/resolve/main/motion_module/mm_sd15_v3.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-animatediff/model -o mm_sd15_v3.safetensors

Prompt_all_in_one = False  # @param {type:"boolean"}
if Prompt_all_in_one:
    # !git clone https://github.com/Physton/sd-webui-prompt-all-in-one.git /content/stable-diffusion-webui/extensions/wildcardssd-webui-prompt-all-in-one

Wildcards = False  # @param {type:"boolean"}
if Wildcards:
    # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-wildcards.git /content/stable-diffusion-webui/extensions/wildcards

ReActor = False  # @param {type:"boolean"}
if ReActor:
    # !git clone https://github.com/Gourieff/sd-webui-reactor /content/stable-diffusion-webui/extensions/sd-webui-reactor
    # !pip install insightface==0.7.3

Rembg = False  # @param {type:"boolean"}
if Rembg:
    # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-rembg.git /content/stable-diffusion-webui/extensions/stable-diffusion-webui-rembg

LoraBlockWeight = False  # @param {type:"boolean"}
if LoraBlockWeight:
    # !git clone https://github.com/hako-mikan/sd-webui-lora-block-weight.git /content/stable-diffusion-webui/extensions/sd-webui-lora-block-weight
    # !wget -q -O /content/stable-diffusion-webui/extensions/sd-webui-lora-block-weight/scripts/elempresets.txt https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/sd-webui-lora-block-weight/elempresets.txt
    # !wget -q -O /content/stable-diffusion-webui/extensions/sd-webui-lora-block-weight/scripts/lbwpresets.txt https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/sd-webui-lora-block-weight/lbwpresets.txt

ColorCorrection = False  # @param {type:"boolean"}
if ColorCorrection:
    # !git clone https://github.com/light-and-ray/sd-webui-color-correction-extras.git /content/stable-diffusion-webui/extensions/sd-webui-color-correction-extras

Mov2Mov = False  # @param {type:"boolean"}
if Mov2Mov:
    # !git clone https://github.com/Scholar01/sd-webui-mov2mov.git /content/stable-diffusion-webui/extensions/sd-webui-mov2mov

XLControlnetModel = False  # @param {type:"boolean"}
if XLControlnetModel:
    # Download ControlNet XL models
    # !aria2c -q -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_canny_128lora.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o sai_xl_canny_128lora.safetensors
    # !aria2c -q -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_depth_128lora.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o sai_xl_depth_128lora.safetensors
    # !aria2c -q -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_sketch_128lora.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o sai_xl_sketch_128lora.safetensors
    # !aria2c -q -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/t2i-adapter_diffusers_xl_openpose.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o t2i-adapter_diffusers_xl_openpose.safetensors
    # !aria2c -q -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/sai_xl_recolor_128lora.safetensors -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o sai_xl_recolor_128lora.safetensors
    # !aria2c -q -c -x 16 -s 16 -k 1M https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/ip-adapter_xl.pth -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o ip-adapter_xl.pth

wd14tagger = False  # @param {type:"boolean"}
if wd14tagger:
    # !git clone https://github.com/picobyte/stable-diffusion-webui-wd14-tagger.git /content/stable-diffusion-webui/extensions/stable-diffusion-webui-wd14-tagger

# %cd /content/stable-diffusion-webui

# !pip uninstall pydantic pydantic_core wandb pytorch_lightning -y
# !pip install "pydantic>=2.0"

# **Create config.json**
config_json_content = '''
{
  "outdir_samples": "",
  "outdir_txt2img_samples": "/content/drive/MyDrive/SD-IMG-OUT/outputs/text",
  "outdir_img2img_samples": "/content/drive/MyDrive/SD-IMG-OUT/outputs/image",
  "outdir_extras_samples": "/content/drive/MyDrive/SD-IMG-OUT/outputs/extras",
  "outdir_grids": "",
  "outdir_txt2img_grids": "/content/drive/MyDrive/SD-IMG-OUT/outputs/grids",
  "outdir_img2img_grids": "/content/drive/MyDrive/SD-IMG-OUT/outputs/grids",
  "outdir_save": "/content/drive/MyDrive/SD-IMG-OUT/outputs/save",
  "outdir_init_images": "/content/drive/MyDrive/SD-IMG-OUT/outputs/init-images"
}
'''
with open('/content/stable-diffusion-webui/config.json', 'w') as f:
    f.write(config_json_content)

# **Reset Git Repositories**
# !git reset --hard
# !git -C /content/stable-diffusion-webui/repositories/stable-diffusion-stability-ai reset --hard

# **Download ControlNet Models**
controlnet_models = {
    "control_v11p_sd15_canny_fp16.safetensors": "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny_fp16.safetensors",
    "control_v11p_sd15_canny_fp16.yaml": "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_canny_fp16.yaml",
    "control_v11f1p_sd15_depth_fp16.safetensors": "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth_fp16.safetensors",
    "control_v11f1p_sd15_depth_fp16.yaml": "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1p_sd15_depth_fp16.yaml",
    "control_v11p_sd15_normalbae_fp16.safetensors": "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae_fp16.safetensors",
    "control_v11p_sd15_normalbae_fp16.yaml": "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_normalbae_fp16.yaml",
    "control_v11p_sd15_mlsd_fp16.safetensors": "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd_fp16.safetensors",
    "control_v11p_sd15_mlsd_fp16.yaml": "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_mlsd_fp16.yaml",
    "control_v11p_sd15_openpose_fp16.safetensors": "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose_fp16.safetensors",
    "control_v11p_sd15_openpose_fp16.yaml": "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_openpose_fp16.yaml",
    "control_v11p_sd15_lineart_fp16.safetensors": "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart_fp16.safetensors",
    "control_v11p_sd15s2_lineart_anime_fp16.safetensors": "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime_fp16.safetensors",
    "control_v11p_sd15_lineart_fp16.yaml": "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_lineart_fp16.yaml",
    "control_v11p_sd15s2_lineart_anime_fp16.yaml": "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15s2_lineart_anime_fp16.yaml",
    "control_v11p_sd15_inpaint_fp16.safetensors": "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint_fp16.safetensors",
    "control_v11p_sd15_inpaint_fp16.yaml": "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_inpaint_fp16.yaml",
    "control_v11p_sd15_scribble_fp16.safetensors": "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble_fp16.safetensors",
    "control_v11p_sd15_scribble_fp16.yaml": "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_scribble_fp16.yaml",
    "control_v11p_sd15_softedge_fp16.safetensors": "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge_fp16.safetensors",
    "control_v11p_sd15_softedge_fp16.yaml": "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11p_sd15_softedge_fp16.yaml",
    "control_v11f1e_sd15_tile_fp16.safetensors": "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile_fp16.safetensors",
    "control_v11f1e_sd15_tile_fp16.yaml": "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11f1e_sd15_tile_fp16.yaml",
    "control_v11e_sd15_shuffle_fp16.safetensors": "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle_fp16.safetensors",
    "control_v11e_sd15_shuffle_fp16.yaml": "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_shuffle_fp16.yaml",
    "control_v11e_sd15_ip2p_fp16.safetensors": "https://huggingface.co/ckpt/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p_fp16.safetensors",
    "control_v11e_sd15_ip2p_fp16.yaml": "https://huggingface.co/ckpt/ControlNet-v1-1/raw/main/control_v11e_sd15_ip2p_fp16.yaml",
    "control_v1p_sd15_qrcode_monster.safetensors": "https://huggingface.co/monster-labs/control_v1p_sd15_qrcode_monster/resolve/main/control_v1p_sd15_qrcode_monster.safetensors",
    "control_v1p_sd15_qrcode_monster.yaml": "https://huggingface.co/monster-labs/control_v1p_sd15_qrcode_monster/resolve/main/control_v1p_sd15_qrcode_monster.yaml",
    "ip-adapter_sd15.pth": "https://huggingface.co/lllyasviel/sd_control_collection/resolve/main/ip-adapter_sd15.pth",
    "ip-adapter-plus-face_sd15.pth": "https://huggingface.co/h94/IP-Adapter/resolve/main/models/ip-adapter-plus-face_sd15.bin",
    "ip-adapter-plus_sd15.pth": "https://huggingface.co/h94/IP-Adapter/resolve/main/models/ip-adapter-plus_sd15.bin"
}

for filename, url in controlnet_models.items():
    # !aria2c -q -c -x 16 -s 16 -k 1M {url} -d /content/stable-diffusion-webui/extensions/sd-webui-controlnet/models -o {filename}

# **Copy Models from Google Drive**
model_paths = {
    "Lora": "/content/drive/MyDrive/SD-Model/Lora",
    "Stable-diffusion": "/content/drive/MyDrive/SD-Model/Checkpoint",
    "VAE": "/content/drive/MyDrive/SD-Model/VAE",
    "ControlNet": "/content/drive/MyDrive/SD-Model/ControlNet",
    "embeddings": "/content/drive/MyDrive/SD-Model/embeddings"
}

for model_name, drive_path in model_paths.items():
    dest_path = f"/content/stable-diffusion-webui/models/{model_name}" if model_name != "embeddings" else "/content/stable-diffusion-webui/embeddings"
    # !mkdir -p {dest_path}
    # !cp -av {drive_path}/* {dest_path}

# @title ### เลือก Config ที่ต้องการ (หากต้องการเซฟ config เพื่อใช้ในอนาคต โปรดอ่านข้อ 3.0.)

Config_name = "ZenityX SD1.5 Optimize V2"  # @param ["ZenityX SD1.5 Optimize V2","ZenityX SD1.5 Optimize","ZenityX SDXL Optimize","Sync with Google Drive","Default"]

config_urls = {
    "ZenityX SD1.5 Optimize V2": {
        "ui-config.json": "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/V3/ui-config.json",
        "styles.csv": "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/styles.csv",
        "config.json": "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/config%20V2/config.json"
    },
    "ZenityX SD1.5 Optimize": {
        "ui-config.json": "https://huggingface.co/zenityx/magmix/resolve/main/ui-config.json",
        "styles.csv": "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/styles.csv",
        "config.json": "https://huggingface.co/zenityx/magmix/resolve/main/config.json"
    },
    "ZenityX SDXL Optimize": {
        "styles.csv": "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/styles.csv",
        "config.json": "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/XLconfig/config.json",
        "ui-config.json": "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/XLconfig/ui-config.json",
        "control_instant_id_sdxl.safetensors": "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/Controlnet%20Model/control_instant_id_sdxl.safetensors",
        "ip-adapter_instant_id_sdxl.pth": "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/Controlnet%20Model/ip-adapter_instant_id_sdxl.pth"
    },
    "Default": {}
}

if Config_name in config_urls:
    files = config_urls[Config_name]
    for filename, url in files.items():
        if filename.endswith(('.safetensors', '.pth')):
            dest = f"/content/stable-diffusion-webui/extensions/sd-webui-controlnet/models/{filename}"
        else:
            dest = f"/content/stable-diffusion-webui/{filename}"
        # !aria2c -q -c -x 16 -s 16 -k 1M {url} -d $(dirname {dest}) -o $(basename {dest})
elif Config_name == "Sync with Google Drive":
    # !cp -av /content/drive/MyDrive/SD-Model/Config/* /content/stable-diffusion-webui

print('\033[32m' + "จัดการไฟล์และติดตั้งเรียบร้อย เริ่มรันโปรแกรมใน 3 2 1 . . . " + '\033[0m')

# **Modify shared_options.py**
# !sed -i -e 's/\["sd_model_checkpoint"\]/\["sd_model_checkpoint","sd_vae","CLIP_stop_at_last_layers","hypertile_enable_unet_secondpass"\]/g' /content/stable-diffusion-webui/modules/shared_options.py

# **Launch the Web UI**
# !python launch.py --listen --enable-insecure-extension-access --theme dark --gradio-queue --multiple --xformers

# %%
#@title ## 1.0.2  สำหรับ Run ใหม่ถ้าค้าง 🔁
#@markdown ถ้าค้างให้กด Stop Cell เดิม (กดให้วงกลมที่กำลังหมุนในตัวหลัก หยุดหมุนก่อน) แล้วค่อย Run ตัวนี้แทน
# %cd /content/stable-diffusion-webui
# !python launch.py --listen --enable-insecure-extension-access --theme dark --gradio-queue --multiple --autolaunch --xformers

# %%
#@title ## 1.1.0  สำหรับดึงโมเดลจาก Google Drive เข้า SD โดยไม่ต้องรันใหม่ทั้งหมด 🔁📂
#@markdown ใช้สำหรับดึงไฟล์จาก Google Drive ที่ใส่เข้าไปเพิ่มในทันที โดยไม่ต้องปิดเปิดใหม่ทั้งหมด โดยให้กด Stop Cell เดิม (กดให้วงกลมที่กำลังหมุนในตัวหลัก หยุดหมุนก่อน) แล้วค่อย Run ตัวนี้แทน

#%cp -av /content/drive/MyDrive/SD-Model/Lora /content/stable-diffusion-webui/models/
#%cp -av /content/drive/MyDrive/SD-Model/Checkpoint/* /content/stable-diffusion-webui/models/Stable-diffusion
#%cp -av /content/drive/MyDrive/SD-Model/VAE /content/stable-diffusion-webui/models/
#%cp -av /content/drive/MyDrive/SD-Model/ControlNet /content/stable-diffusion-webui/models/

#src_dir = "/content/drive/MyDrive/SD-Model/Checkpoint/"
#dest_dir = "/content/stable-diffusion-webui/models/Stable-diffusion/"

#for filename in os.listdir(src_dir):
#   src_file = os.path.join(src_dir, filename)
#    dest_file = os.path.join(dest_dir, filename)
#    if os.path.isfile(src_file) and not os.path.isfile(dest_file):
#        shutil.copy2(src_file, dest_file)
#        print(f"Copied {filename}")
#    else:
#        print(f"File {filename} มีอยู่แล้ว ข้ามการดาวน์โหลด")
#
import os
import shutil

def copy_unique_files(src_dir, dest_dir):
    for filename in os.listdir(src_dir):
        src_file = os.path.join(src_dir, filename)
        dest_file = os.path.join(dest_dir, filename)
        if os.path.isfile(src_file) and not os.path.isfile(dest_file):
            shutil.copy2(src_file, dest_file)
            print(f"Copied {filename}")
        else:
            print(f"File {filename} มีอยู่แล้ว ข้ามการดาวน์โหลด")

# ตั้งค่าโฟลเดอร์ต้นทางและปลายทาง
folders = [
    ("/content/drive/MyDrive/SD-Model/Checkpoint/", "/content/stable-diffusion-webui/models/Stable-diffusion/"),
    ("/content/drive/MyDrive/SD-Model/Lora/", "/content/stable-diffusion-webui/models/Lora/"),
    ("/content/drive/MyDrive/SD-Model/VAE/", "/content/stable-diffusion-webui/models/VAE/"),
    ("/content/drive/MyDrive/SD-Model/ControlNet/", "/content/stable-diffusion-webui/models/ControlNet/"),
    # เพิ่มคู่ของโฟลเดอร์ต้นทางและปลายทางเพิ่มเติมตามที่ต้องการ
]

# วนลูปเรียกใช้ฟังก์ชันสำหรับแต่ละคู่ของโฟลเดอร์ต้นทางและปลายทาง
for src_dir, dest_dir in folders:
    copy_unique_files(src_dir, dest_dir)

print('\033[32m' + "ดึงทุกไฟล์ครบเรียบร้อย เริ่มรันโปรแกรม ใน 3 2 1 . . . " + '\033[0m')

# %cd /content/stable-diffusion-webui
# !python launch.py --listen --enable-insecure-extension-access --theme dark --gradio-queue --multiple --autolaunch --xformers

# %% [markdown]
# # 2.0 Install to Google Drive 📂 (Run ครั้งแรกครั้งเดียว หรือเมื่ออยากโหลดโมเดลเพิ่ม)

# %%
#@title ## 2.0.1  สำหรับสร้างโฟลเดอร์ และดาวน์โหลดโมเดล ลง Google Drive  📂

import os

# %cd /content
from google.colab import drive
drive.mount('/content/drive')

# !apt-get update
# !apt-get install -y aria2 libcairo2-dev pkg-config python3-dev

main_folders = ["SD-Model"]

# สร้างโฟลเดอร์หลัก
for main_folder_name in main_folders:
    main_folder_path = "/content/drive/MyDrive/" + main_folder_name

    # ตรวจสอบว่าโฟลเดอร์หลักยังไม่มีอยู่ หากยังไม่มีให้สร้าง
    if not os.path.exists(main_folder_path):
        os.mkdir(main_folder_path)
        print(f"สร้างโฟลเดอร์หลัก {main_folder_name} สำเร็จ")
    else:
        print(f"โฟลเดอร์หลัก {main_folder_name} มีอยู่แล้ว")

# รายชื่อโฟลเดอร์ย่อยที่คุณต้องการสร้างภายในโฟลเดอร์หลัก
sub_folders = ["Checkpoint", "Lora", "VAE","ControlNet","embeddings"]

# สร้างโฟลเดอร์ย่อยภายในโฟลเดอร์หลัก
for sub_folder_name in sub_folders:
    sub_folder_path = main_folder_path + "/" + sub_folder_name

# ตรวจสอบว่าโฟลเดอร์ย่อยยังไม่มีอยู่ หากยังไม่มีให้สร้าง
    if not os.path.exists(sub_folder_path):
        os.mkdir(sub_folder_path)
        print(f"สร้างโฟลเดอร์ย่อย {sub_folder_name} ภายใน {main_folder_name} สำเร็จ")
    else:
        print(f"โฟลเดอร์ย่อย {sub_folder_name} ภายใน {main_folder_name} มีอยู่แล้ว")

# @markdown เลือกโมเดลที่ต้องการดาวน์โหลดลง Google Drive **ถ้าเคยทำแล้ว ไม่ต้องทำซ้ำ** หรือในกรณีที่ต้องการดาวน์โหลด Model เพิ่มสามารถมาเลือก Run ใหม่ได้

# @markdown ###Checkpoint

#ตั้งค่าพารามิเตอร์สำหรับดาวน์โหลด
download_path = "/content/drive/MyDrive/SD-Model/Checkpoint/"

# กำหนดสถานะการดาวน์โหลดสำหรับแต่ละไฟล์
MajicmixRealistic_v7 = False # @param {type:"boolean"}
Magmix_v8 = True # @param {type:"boolean"}
ZenityXmix_inpainting = False # @param {type:"boolean"}

# @markdown ###Checkpoint XL
LeosamsHelloworldSDXL_v40 = False # @param {type:"boolean"}
JuggernautXL_v8 = False # @param {type:"boolean"}

# @markdown ###Checkpoint For Architecture
Architecturerealmix_v11 = False # @param {type:"boolean"}
RealisticVisionV60B1_v60B1VAE = False # @param {type:"boolean"}

# ฟังก์ชันสำหรับดาวน์โหลดไฟล์
def download_file(file_name, file_url, should_download):
    if should_download and not os.path.exists(os.path.join(download_path, file_name)):
        print(f"กำลังดาวน์โหลด {file_url} to {download_path}")
        # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {file_url} -d {download_path}  -o {file_name}
        print("ดาวน์โหลดสำเร็จ")
    elif os.path.exists(os.path.join(download_path, file_name)):
        print(f"File {file_name} มีอยู่แล้ว. ข้ามการดาวน์โหลด.")

# รายการของไฟล์ที่จะดาวน์โหลด
files_to_download = [
    ("majicmixRealistic_v7.safetensors", "https://huggingface.co/zenityx/magmix/resolve/main/majicmixRealistic_v7.safetensors", MajicmixRealistic_v7),
    ("magmix_v80.safetensors", "https://huggingface.co/zenityx/magmix/resolve/main/magmix_v80.safetensors", Magmix_v8),
    ("architecturerealmix_v11.safetensors", "https://huggingface.co/zenityx/Model-backup/resolve/main/architecturerealmix_v11.safetensors", Architecturerealmix_v11),
    ("realisticVisionV60B1_v60B1VAE.safetensors", "https://huggingface.co/zenityx/Model-backup/resolve/main/realisticVisionV60B1_v60B1VAE.safetensors", RealisticVisionV60B1_v60B1VAE),
    ("leosamsHelloworldSDXL_helloworldSDXL40.safetensors", "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/leosamsHelloworldSDXL_helloworldSDXL40.safetensors", LeosamsHelloworldSDXL_v40),
    ("juggernautXL_v8Rundiffusion.safetensors", "https://huggingface.co/zenityx/ZenityX_SD_Webui_Colab/resolve/main/juggernautXL_v8Rundiffusion.safetensors", JuggernautXL_v8),
    ("zenityXmix.inpainting.safetensor", "https://huggingface.co/zenityx/zenityX_inpaint/resolve/main/zenityXmix.inpainting.safetensors", ZenityXmix_inpainting),
    # เพิ่มไฟล์ในอนาคตได้ที่นี่
]

# วนลูปดาวน์โหลดไฟล์
for file_name, file_url, should_download in files_to_download:
    download_file(file_name, file_url, should_download)
# @markdown ###VAE
# ดาวน์โหลด VAE
download_path_VAE = "/content/drive/MyDrive/SD-Model/VAE/"
file_url = "https://huggingface.co/zenityx/magmix/resolve/main/vae-ft-mse-840000-ema-pruned.safetensors"
file_name = "vae-ft-mse-840000-ema-pruned.safetensors"
full_file_path = os.path.join(download_path_VAE, file_name)

VAE_840000 = True # @param {type:"boolean"}
if VAE_840000 == True:
  if not os.path.exists(full_file_path):
    if not os.path.exists(download_path_VAE):
        os.makedirs(download_path_VAE)
    print(f"กำลังดาวน์โหลด {file_url} to {download_path_VAE}")
    # !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M $file_url -d $download_path_VAE -o $file_name
    print("ดาวน์โหลดสำเร็จ")
  else:
    print(f"File {file_name} มีอยู่แล้ว. ข้ามการดาวน์โหลด.")
else:
  ()

# @markdown ### แบบใช้ Link
# @markdown รองรับลิงค์ Google Drive, CivitAI, Huggingface สามารถดาวน์โหลดพร้อมกันได้หลายลิงค์ โดยใช้ , (ลูกน้ำ) ขั้นกลางระหว่างลิงค์

# @markdown ### Checkpoint
modelUrls = ""  # @param {'type': 'string'}

def install(url):
    base_name = os.path.basename(url)

    if "drive.google.com" in url:
        # !gdown --fuzzy {url}
    elif "huggingface.co" in url:
        if "/blob/" in url:
            url = url.replace("/blob/", "/resolve/")
        # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d /content/drive/MyDrive/SD-Model/Checkpoint -o {base_name} {url}
    else:
        # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d /content/drive/MyDrive/SD-Model/Checkpoint {url}

if modelUrls:
    urls = modelUrls.split(",")
    for url in urls:
        install(url.strip())

# @markdown ### Lora
loraUrls = ""  # @param {'type': 'string'}

def install(url):
    base_name = os.path.basename(url)

    if "drive.google.com" in url:
        # !gdown --fuzzy {url}
    elif "huggingface.co" in url:
        if "/blob/" in url:
            url = url.replace("/blob/", "/resolve/")
        # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d /content/drive/MyDrive/SD-Model/Lora -o {base_name} {url}
    else:
        # !aria2c --console-log-level=error --summary-interval=10 -c -x 16 -k 1M -s 16 -d /content/drive/MyDrive/SD-Model/Lora {url}

if loraUrls:
    urls = loraUrls.split(",")
    for url in urls:
        install(url.strip())

print('\033[32m' + "สร้างโฟลเดอร์ และดาวน์โหลดโมเดล สำหรับ Google drive สำเร็จ" + '\033[0m')
print('\033[34m' + "โปรด Run Cell 2.0.1 เพื่อเริ่มใช้งาน" + '\033[0m')

# %% [markdown]
# # 3.0 Save Configuration to Google Drive 💾
# สำหรับเซฟ Config และการตั้งค่าต่างๆ ไว้ใช้ในครั้งถัดไป โดยใช้เฉพาะเมื่อต้องการแก้ไข Config (ไม่ต้องกดทุกครั้ง) โดยมีขั้นตอนดังนี้
# 1. เข้าหน้า Setting บน Webui
# 2. คลิก Apply settings เพื่อเซฟ Setting ด้านใน (ในกรณีไม่ได้แก้ไข Setting ด้านใน ไม่จำเป็นต้องกด)
# 2. เลือก Defaults ในแถบด้านล้างซ้าย เลือก Apply เพื่อเซฟ Ui Config (Config ต่างๆ บน Webui เช่น Sempling Methods, Sampling Step, Prompt เริ่มต้น และอื่นๆ)
# 3. กด Stop Cell หลัก และรัน Cell ในข้อ 3.0.1 เพื่อบันทึกลงไฟล์ Config ลง Google Drive
# 4. ในครั้งถัดไปที่เริ่มรันใหม่ ให้เลือก  Config_name เป็น **Sync with Google Drive** บน Cell หลัก (2.0.)

# %%
#@title ## 3.0.1 Run เพื่อ Save Configuration to Google Drive
#@markdown ใช้สำหรับ Save Config ที่ตั้งค่าไว้ทั้งหมด ไปใช้ในครั้งถัดไป

folder_path = '/content/drive/MyDrive/SD-Model/Config/'

# ตรวจสอบว่าโฟลเดอร์มีอยู่หรือไม่
if not os.path.exists(folder_path):
    # ถ้าไม่มี, สร้างโฟลเดอร์
    os.makedirs(folder_path)
    print(f'โฟลเดอร์ได้ถูกสร้างที่: {folder_path}')
else:
    ()

# %cp -av /content/stable-diffusion-webui/config.json /content/drive/MyDrive/SD-Model/Config/
# %cp -av /content/stable-diffusion-webui/styles.csv /content/drive/MyDrive/SD-Model/Config/
# %cp -av /content/stable-diffusion-webui/ui-config.json /content/drive/MyDrive/SD-Model/Config/

print(f'Save Config เรียบร้อย')
